# %%
import pandas as pd
import os
from tqdm.auto import tqdm
from pdb_processor import PDBProcessor
from Bio.PDB import PDBParser

# %%
df = pd.read_excel("PPB-Affinity.xlsx").drop(columns=["Unnamed: 0"])
df.head()
# Out:
#   Source Data Set                  Complex ID   PDB Mutations Ligand Chains  \
# 0     SKEMPI v2.0     1A22:A, B::PMID=7504735  1A22       NaN             A
# 1     SKEMPI v2.0     1A4Y:A, B::PMID=9050852  1A4Y       NaN             A
# 2     SKEMPI v2.0     1ACB:E, I::PMID=9048543  1ACB       NaN             E
# 3     SKEMPI v2.0  1AHW:A, B, C::PMID=9480775  1AHW       NaN          A, B
# 4     SKEMPI v2.0     1AK4:A, D::PMID=9223641  1AK4       NaN             A
#
#   Receptor Chains                Ligand Name         Receptor Name  \
# 0               B       Human growth hormone   hGH binding protein
# 1               B     Ribonuclease inhibitor            Angiogenin
# 2               I  Bovine alpha-chymotrypsin               Eglin c
# 3               C     Immunoglobulin fab 5G9         Tissue factor
# 4               D              Cyclophilin A  HIV-1 capsid protein
#
#           KD(M) Affinity Method   Structure Method Temperature(K)  \
# 0  9.000000e-10             SPR  X-RAY DIFFRACTION            298
# 1  5.000000e-16           Other  X-RAY DIFFRACTION            298
# 2  1.490000e-12            IASP  X-RAY DIFFRACTION            294
# 3  3.400000e-09            IASP  X-RAY DIFFRACTION   298(assumed)
# 4  1.200000e-05             SPR  X-RAY DIFFRACTION   298(assumed)
#
#    Resolution(Å)  PDB PubMed ID PDB Release Date Affinity PubMed ID  \
# 0           2.60      9571026.0       1998-04-29            7504735
# 1           2.00      9311977.0       1998-10-14            9050852
# 2           2.00      1583684.0       1993-10-31            9048543
# 3           3.00      9480775.0       1998-02-25            9480775
# 4           2.36      8980234.0       1997-10-15            9223641
#
#   Affinity Release Date Subgroup
# 0            1993 Dec 5      NaN
# 1            1997 Mar 4      NaN
# 2           1997 Feb 18      NaN
# 3            1998 Feb 6      NaN
# 4           1997 Jun 27      NaN

# %% [markdown]
# # Clean the data from wrong entries

# %% [markdown]
# The following entries have at least one mutation in which the specified
# position contains an amino acid that is different from the wild-type amino
# specified in the mutation itself. We don't know why this is the case, but we
# will drop these entries for safety.

# %%
ids_to_drop = [
    # The mutation is C_K8E, but the wt aa at position 8 in chain C is L, not K.
    "3QIW:A, B, C, D, E:C_K8E:PMID=21490152",
    # One of the mutations E_G50A, but the wt aa at position 50 in chain E is I not G
    "2P5E:A, C, D, E:D_G97D, D_Q51T, D_S52P, D_S53W, D_S96L, D_S99T, D_T95L, E_A51I, E_G50A, E_G52Q, E_I53T, E_V95L:PMID=17644531",
    # The mutation is C_K8R, but the wt aa at position 8 in chain C is L not K
    "3QIU:A, B, C, D, E:C_K8R:PMID=21490152",
]
df = df[~df["Complex ID"].isin(ids_to_drop)].reset_index(drop=True)

# %% [markdown]
# ## Chain Validation and Missing Chains Detection
# This section validates the presence of ligand and receptor chains specified in the data against actual PDB files.
#
# **Chain validation and correction steps (for each ligand and receptor in each row):**
# 1. Check if the chain is present in the PDB file.
# 2. If the chain is not present, check if the chain id is lowercase, and its uppercase version is present in the PDB file. If so, correct the corresponding list of chains to include the uppercase version only.
# 3. If the second check fails, drop the row.
# 4. If the chain is an empty string for example, ', C, D', drop the row.

# %%
parser = PDBParser(QUIET=True)
complex_ids_with_missing_chains = dict()
for i, row in tqdm(df.iterrows(), total=len(df)):
    pdb_id = row["PDB"]
    complex_id = row["Complex ID"]
    source_data = row["Source Data Set"]
    ligand_chains = row["Ligand Chains"].replace(" ", "").split(",")
    receptor_chains = row["Receptor Chains"].replace(" ", "").split(",")
    if source_data in ["SKEMPI v2.0", "Affinity Benchmark v5.5", "ATLAS"]:
        pdb_path = os.path.join("PDB", source_data, f"{pdb_id}.pdb")
    elif source_data == "SAbDab":
        pdb_path = os.path.join(
            "PDB", source_data, f"{pdb_id.lower()}.pdb"
        )
    elif source_data == "PDBbind v2020":
        pdb_path = os.path.join(
            "PDB", source_data, f"{pdb_id.lower()}.ent.pdb"
        )
    else:
        raise ValueError(f"Unknown source data set: {source_data}")
    structure = parser.get_structure(pdb_id, pdb_path)
    chains_in_pdb = [chain.id for chain in list(structure.get_chains())]
    for chain in ligand_chains:
        if chain not in chains_in_pdb:
            if chain.islower() and chain.upper() in ligand_chains:
                df.loc[i, "Ligand Chains"] = row["Ligand Chains"].replace(
                    f", {chain}", ""
                )
                continue
            if complex_id not in complex_ids_with_missing_chains:
                complex_ids_with_missing_chains[complex_id] = []
            complex_ids_with_missing_chains[complex_id].append(
                f"Missing ligand chain {chain}"
            )
    for chain in receptor_chains:
        if chain not in chains_in_pdb:
            if chain.islower() and chain.upper() in receptor_chains:
                df.loc[i, "Receptor Chains"] = row[
                    "Receptor Chains"
                ].replace(f", {chain}", "")
                continue
            if complex_id not in complex_ids_with_missing_chains:
                complex_ids_with_missing_chains[complex_id] = []
            complex_ids_with_missing_chains[complex_id].append(
                f"Missing receptor chain {chain}"
            )
print(
    "Found total of",
    len(complex_ids_with_missing_chains),
    "complexes with missing chains. Listing the complexes with missing chains:",
)

for complex_id, missing_chains in complex_ids_with_missing_chains.items():
    print(complex_id, missing_chains)
# Out:
#   0%|          | 0/12059 [00:00<?, ?it/s]
# Found total of 11 complexes with missing chains. Listing the complexes with missing chains:
# 5Y9J:A, B, C, H, L::PMID=Shin et al., 2018 ['Missing receptor chain B', 'Missing receptor chain C']
# 3LVK:A, B, C::PMID=23281480 ['Missing ligand chain C']
# 3WD5:A, B, C, H, L::PMID=Hu et al., 2013 ['Missing receptor chain B', 'Missing receptor chain C']
# 1DEE:, C, D, G::PMID=10805799 ['Missing ligand chain ']
# 2WUB:A, H, J::PMID=nan ['Missing ligand chain J']
# 3PL6:A, B, C, D, E::PMID=21199956 ['Missing receptor chain E']
# 4EEF:, A, B, G::PMID=22634563 ['Missing ligand chain ']
# 5KVE:E, H, L::PMID=27475895 ['Missing ligand chain H']
# 6B0G:, C, D, E::PMID=29146922 ['Missing receptor chain ']
# 6O07:A, C, D::PMID=31155310 ['Missing receptor chain D']
# 4L3E:A, B, C, D, E:D_D26Y, E_L98W:PMID=24550723 ['Missing ligand chain B']

# %%
# Drop entries with missing chains
df = df[~df["Complex ID"].isin(list(complex_ids_with_missing_chains.keys()))]

# %%
ligand_sequences = []
receptor_sequences = []
pp = PDBProcessor()
for _, row in tqdm(df.iterrows(), total=len(df)):
    pdb_id = row["PDB"]
    complex_id = row["Complex ID"]
    source_data = row["Source Data Set"]
    mutations = row["Mutations"]
    if pd.isna(mutations):
        mutations = None
    else:
        mutations = mutations.replace(" ", "").split(",")
    ligand_chains = row["Ligand Chains"].replace(" ", "").split(",")
    receptor_chains = row["Receptor Chains"].replace(" ", "").split(",")
    if source_data in ["SKEMPI v2.0", "Affinity Benchmark v5.5", "ATLAS"]:
        pdb_path = os.path.join("PDB", source_data, f"{pdb_id}.pdb")
    elif source_data == "SAbDab":
        pdb_path = os.path.join("PDB", source_data, f"{pdb_id.lower()}.pdb")
        ligand_chains = set(ligand_chains)
        receptor_chains = set(receptor_chains)
        chains_to_remove = []
        for chain in list(ligand_chains):
            if chain.islower() and chain.upper() in ligand_chains:
                ligand_chains.remove(chain)
        for chain in list(receptor_chains):
            if chain.islower() and chain.upper() in receptor_chains:
                receptor_chains.remove(chain)
        ligand_chains = list(ligand_chains)
        receptor_chains = list(receptor_chains)
    elif source_data == "PDBbind v2020":
        pdb_path = os.path.join(
            "PDB", source_data, f"{pdb_id.lower()}.ent.pdb"
        )
    else:
        raise ValueError(f"Unknown source data set: {source_data}")
    if pdb_id == "3QIB" and mutations is not None and source_data == "ATLAS":
        for i, mutation in enumerate(mutations):
            # all mutations associated with 3QIB, ATLAS, and chain C are off by
            # one residue. This happened in multiple entries in the dataset,
            # so we correct it here.
            if mutation.startswith("C_"):
                mutation_loc = mutation.split("_")[1][1:-1]
                mutations[i] = mutation.replace(
                    mutation_loc, str(int(mutation_loc) + 1)
                )

    protein_seqs = pp.pdb_to_processed_seqs(
        pdb_id=pdb_id,
        pdb_path=pdb_path,
        chains=ligand_chains + receptor_chains,
        mutations=mutations,
        recover_missing_residues=True,
        remove_unk_residues=True,
    )
    ligand_seq = ",".join([protein_seqs[chain] for chain in ligand_chains])
    receptor_seq = ",".join([protein_seqs[chain] for chain in receptor_chains])
    ligand_sequences.append(ligand_seq)
    receptor_sequences.append(receptor_seq)
    
df["Ligand Sequences"] = ligand_sequences
df["Receptor Sequences"] = receptor_sequences
df.to_csv("PPB_Affinity_processed.csv", index=False)
# Out:
#   0%|          | 0/12048 [00:00<?, ?it/s]
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:268: UserWarning: Could not find the missing residues for chain D in PDB 1AO7 due to a misalignment between seqeuences from ATOM records and SEQRES. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:268: UserWarning: Could not find the missing residues for chain E in PDB 1AO7 due to a misalignment between seqeuences from ATOM records and SEQRES. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:268: UserWarning: Could not find the missing residues for chain D in PDB 1BD2 due to a misalignment between seqeuences from ATOM records and SEQRES. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:268: UserWarning: Could not find the missing residues for chain E in PDB 1BD2 due to a misalignment between seqeuences from ATOM records and SEQRES. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:439: UserWarning: Could not find the missing residues for chain E in PDB 1CSE due to a misalignment between seqeuences from ATOM records and SEQRES. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:268: UserWarning: Could not find the missing residues for chain E in PDB 1CSO due to a misalignment between seqeuences from ATOM records and SEQRES. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:268: UserWarning: Could not find the missing residues for chain E in PDB 1CT0 due to a misalignment between seqeuences from ATOM records and SEQRES. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:268: UserWarning: Could not find the missing residues for chain E in PDB 1CT2 due to a misalignment between seqeuences from ATOM records and SEQRES. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:268: UserWarning: Could not find the missing residues for chain E in PDB 1CT4 due to a misalignment between seqeuences from ATOM records and SEQRES. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:268: UserWarning: Could not find the missing residues for chain H in PDB 1DAN due to a misalignment between seqeuences from ATOM records and SEQRES. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:268: UserWarning: Could not find the missing residues for chain B in PDB 1DQJ due to a misalignment between seqeuences from ATOM records and SEQRES. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:268: UserWarning: Could not find the missing residues for chain A in PDB 1EAW due to a misalignment between seqeuences from ATOM records and SEQRES. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:268: UserWarning: Could not find the missing residues for chain A in PDB 1F5R due to a misalignment between seqeuences from ATOM records and SEQRES. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:268: UserWarning: Could not find the missing residues for chain E in PDB 1FY8 due to a misalignment between seqeuences from ATOM records and SEQRES. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:268: UserWarning: Could not find the missing residues for chain G in PDB 1GC1 due to a misalignment between seqeuences from ATOM records and SEQRES. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:268: UserWarning: Could not find the missing residues for chain A in PDB 1JCK due to a misalignment between seqeuences from ATOM records and SEQRES. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:268: UserWarning: Could not find the missing residues for chain L in PDB 1JRH due to a misalignment between seqeuences from ATOM records and SEQRES. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:268: UserWarning: Could not find the missing residues for chain H in PDB 1JRH due to a misalignment between seqeuences from ATOM records and SEQRES. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:268: UserWarning: Could not find the missing residues for chain F in PDB 1LP9 due to a misalignment between seqeuences from ATOM records and SEQRES. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:268: UserWarning: Could not find the missing residues for chain E in PDB 1LP9 due to a misalignment between seqeuences from ATOM records and SEQRES. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:268: UserWarning: Could not find the missing residues for chain D in PDB 1MI5 due to a misalignment between seqeuences from ATOM records and SEQRES. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:439: UserWarning: Could not find the missing residues for chain E in PDB 1MI5 due to a misalignment between seqeuences from ATOM records and SEQRES. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:268: UserWarning: Could not find the missing residues for chain H in PDB 1NCA due to a misalignment between seqeuences from ATOM records and SEQRES. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:268: UserWarning: Could not find the missing residues for chain N in PDB 1NCA due to a misalignment between seqeuences from ATOM records and SEQRES. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:268: UserWarning: Could not find the missing residues for chain N in PDB 1NMB due to a misalignment between seqeuences from ATOM records and SEQRES. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:268: UserWarning: Could not find the missing residues for chain E in PDB 1PPF due to a misalignment between seqeuences from ATOM records and SEQRES. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:268: UserWarning: Could not find the missing residues for chain D in PDB 1QSE due to a misalignment between seqeuences from ATOM records and SEQRES. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:268: UserWarning: Could not find the missing residues for chain E in PDB 1QSE due to a misalignment between seqeuences from ATOM records and SEQRES. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:439: UserWarning: Could not find the missing residues for chain E in PDB 1R0R due to a misalignment between seqeuences from ATOM records and SEQRES. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:342: UserWarning: Sequence length mismatch for chain A in PDB 1S1Q between the raw PDB and the PDB in the data. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:342: UserWarning: Sequence length mismatch for chain B in PDB 1S1Q between the raw PDB and the PDB in the data. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:268: UserWarning: Could not find the missing residues for chain A in PDB 1SBB due to a misalignment between seqeuences from ATOM records and SEQRES. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:268: UserWarning: Could not find the missing residues for chain E in PDB 1SGD due to a misalignment between seqeuences from ATOM records and SEQRES. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:268: UserWarning: Could not find the missing residues for chain E in PDB 1SGE due to a misalignment between seqeuences from ATOM records and SEQRES. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:268: UserWarning: Could not find the missing residues for chain E in PDB 1SGN due to a misalignment between seqeuences from ATOM records and SEQRES. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:268: UserWarning: Could not find the missing residues for chain E in PDB 1SGP due to a misalignment between seqeuences from ATOM records and SEQRES. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:268: UserWarning: Could not find the missing residues for chain E in PDB 1SGQ due to a misalignment between seqeuences from ATOM records and SEQRES. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:268: UserWarning: Could not find the missing residues for chain E in PDB 1SGY due to a misalignment between seqeuences from ATOM records and SEQRES. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:268: UserWarning: Could not find the missing residues for chain E in PDB 1SMF due to a misalignment between seqeuences from ATOM records and SEQRES. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:268: UserWarning: Could not find the missing residues for chain L in PDB 1YQV due to a misalignment between seqeuences from ATOM records and SEQRES. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:268: UserWarning: Could not find the missing residues for chain H in PDB 1YQV due to a misalignment between seqeuences from ATOM records and SEQRES. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:268: UserWarning: Could not find the missing residues for chain D in PDB 2AK4 due to a misalignment between seqeuences from ATOM records and SEQRES. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:268: UserWarning: Could not find the missing residues for chain E in PDB 2AK4 due to a misalignment between seqeuences from ATOM records and SEQRES. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:439: UserWarning: Could not find the missing residues for chain L in PDB 2B2X due to a misalignment between seqeuences from ATOM records and SEQRES. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:439: UserWarning: Could not find the missing residues for chain A in PDB 2E7L due to a misalignment between seqeuences from ATOM records and SEQRES. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:268: UserWarning: Could not find the missing residues for chain D in PDB 2E7L due to a misalignment between seqeuences from ATOM records and SEQRES. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:268: UserWarning: Could not find the missing residues for chain E in PDB 2FTL due to a misalignment between seqeuences from ATOM records and SEQRES. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:268: UserWarning: Could not find the missing residues for chain A in PDB 2G2U due to a misalignment between seqeuences from ATOM records and SEQRES. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:268: UserWarning: Could not find the missing residues for chain A in PDB 2G2W due to a misalignment between seqeuences from ATOM records and SEQRES. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:268: UserWarning: Could not find the missing residues for chain F in PDB 2J8U due to a misalignment between seqeuences from ATOM records and SEQRES. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:268: UserWarning: Could not find the missing residues for chain E in PDB 2J8U due to a misalignment between seqeuences from ATOM records and SEQRES. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:268: UserWarning: Could not find the missing residues for chain F in PDB 2JCC due to a misalignment between seqeuences from ATOM records and SEQRES. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:268: UserWarning: Could not find the missing residues for chain E in PDB 2JCC due to a misalignment between seqeuences from ATOM records and SEQRES. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:268: UserWarning: Could not find the missing residues for chain H in PDB 2JEL due to a misalignment between seqeuences from ATOM records and SEQRES. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:268: UserWarning: Could not find the missing residues for chain E in PDB 2NU0 due to a misalignment between seqeuences from ATOM records and SEQRES. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:268: UserWarning: Could not find the missing residues for chain E in PDB 2NU1 due to a misalignment between seqeuences from ATOM records and SEQRES. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:268: UserWarning: Could not find the missing residues for chain E in PDB 2NU2 due to a misalignment between seqeuences from ATOM records and SEQRES. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:268: UserWarning: Could not find the missing residues for chain E in PDB 2NU4 due to a misalignment between seqeuences from ATOM records and SEQRES. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:268: UserWarning: Could not find the missing residues for chain H in PDB 2NY7 due to a misalignment between seqeuences from ATOM records and SEQRES. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:268: UserWarning: Could not find the missing residues for chain G in PDB 2NY7 due to a misalignment between seqeuences from ATOM records and SEQRES. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:439: UserWarning: Could not find the missing residues for chain B in PDB 2OI9 due to a misalignment between seqeuences from ATOM records and SEQRES. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:268: UserWarning: Could not find the missing residues for chain C in PDB 2OI9 due to a misalignment between seqeuences from ATOM records and SEQRES. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:439: UserWarning: Could not find the missing residues for chain B in PDB 2PCC due to a misalignment between seqeuences from ATOM records and SEQRES. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:268: UserWarning: Could not find the missing residues for chain E in PDB 2SGP due to a misalignment between seqeuences from ATOM records and SEQRES. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:268: UserWarning: Could not find the missing residues for chain E in PDB 2SGQ due to a misalignment between seqeuences from ATOM records and SEQRES. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:268: UserWarning: Could not find the missing residues for chain F in PDB 2UWE due to a misalignment between seqeuences from ATOM records and SEQRES. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:268: UserWarning: Could not find the missing residues for chain E in PDB 2UWE due to a misalignment between seqeuences from ATOM records and SEQRES. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:268: UserWarning: Could not find the missing residues for chain A in PDB 3BIW due to a misalignment between seqeuences from ATOM records and SEQRES. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:439: UserWarning: Could not find the missing residues for chain E in PDB 3BIW due to a misalignment between seqeuences from ATOM records and SEQRES. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:439: UserWarning: Could not find the missing residues for chain C in PDB 3BK3 due to a misalignment between seqeuences from ATOM records and SEQRES. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:268: UserWarning: Could not find the missing residues for chain B in PDB 3BN9 due to a misalignment between seqeuences from ATOM records and SEQRES. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:268: UserWarning: Could not find the missing residues for chain E in PDB 3BTD due to a misalignment between seqeuences from ATOM records and SEQRES. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:268: UserWarning: Could not find the missing residues for chain E in PDB 3BTE due to a misalignment between seqeuences from ATOM records and SEQRES. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:268: UserWarning: Could not find the missing residues for chain E in PDB 3BTF due to a misalignment between seqeuences from ATOM records and SEQRES. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:268: UserWarning: Could not find the missing residues for chain E in PDB 3BTG due to a misalignment between seqeuences from ATOM records and SEQRES. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:268: UserWarning: Could not find the missing residues for chain E in PDB 3BTH due to a misalignment between seqeuences from ATOM records and SEQRES. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:268: UserWarning: Could not find the missing residues for chain E in PDB 3BTM due to a misalignment between seqeuences from ATOM records and SEQRES. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:268: UserWarning: Could not find the missing residues for chain E in PDB 3BTQ due to a misalignment between seqeuences from ATOM records and SEQRES. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:268: UserWarning: Could not find the missing residues for chain E in PDB 3BTT due to a misalignment between seqeuences from ATOM records and SEQRES. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:268: UserWarning: Could not find the missing residues for chain E in PDB 3BTW due to a misalignment between seqeuences from ATOM records and SEQRES. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:268: UserWarning: Could not find the missing residues for chain A in PDB 3BX1 due to a misalignment between seqeuences from ATOM records and SEQRES. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:439: UserWarning: Could not find the missing residues for chain A in PDB 3C60 due to a misalignment between seqeuences from ATOM records and SEQRES. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:268: UserWarning: Could not find the missing residues for chain D in PDB 3D3V due to a misalignment between seqeuences from ATOM records and SEQRES. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:268: UserWarning: Could not find the missing residues for chain E in PDB 3D3V due to a misalignment between seqeuences from ATOM records and SEQRES. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:268: UserWarning: Could not find the missing residues for chain D in PDB 3H9S due to a misalignment between seqeuences from ATOM records and SEQRES. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:268: UserWarning: Could not find the missing residues for chain E in PDB 3H9S due to a misalignment between seqeuences from ATOM records and SEQRES. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:268: UserWarning: Could not find the missing residues for chain G in PDB 3IDX due to a misalignment between seqeuences from ATOM records and SEQRES. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:268: UserWarning: Could not find the missing residues for chain L in PDB 3LZF due to a misalignment between seqeuences from ATOM records and SEQRES. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:268: UserWarning: Could not find the missing residues for chain H in PDB 3LZF due to a misalignment between seqeuences from ATOM records and SEQRES. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:268: UserWarning: Could not find the missing residues for chain A in PDB 3N4I due to a misalignment between seqeuences from ATOM records and SEQRES. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:439: UserWarning: Could not find the missing residues for chain H in PDB 3N85 due to a misalignment between seqeuences from ATOM records and SEQRES. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:268: UserWarning: Could not find the missing residues for chain L in PDB 3NGB due to a misalignment between seqeuences from ATOM records and SEQRES. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:268: UserWarning: Could not find the missing residues for chain G in PDB 3NGB due to a misalignment between seqeuences from ATOM records and SEQRES. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:268: UserWarning: Could not find the missing residues for chain A in PDB 3NPS due to a misalignment between seqeuences from ATOM records and SEQRES. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:439: UserWarning: Could not find the missing residues for chain B in PDB 3NPS due to a misalignment between seqeuences from ATOM records and SEQRES. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:268: UserWarning: Could not find the missing residues for chain C in PDB 3NPS due to a misalignment between seqeuences from ATOM records and SEQRES. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:268: UserWarning: Could not find the missing residues for chain D in PDB 3PWP due to a misalignment between seqeuences from ATOM records and SEQRES. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:268: UserWarning: Could not find the missing residues for chain E in PDB 3PWP due to a misalignment between seqeuences from ATOM records and SEQRES. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:268: UserWarning: Could not find the missing residues for chain D in PDB 3QFJ due to a misalignment between seqeuences from ATOM records and SEQRES. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:268: UserWarning: Could not find the missing residues for chain E in PDB 3QFJ due to a misalignment between seqeuences from ATOM records and SEQRES. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:268: UserWarning: Could not find the missing residues for chain A in PDB 3QHY due to a misalignment between seqeuences from ATOM records and SEQRES. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:268: UserWarning: Could not find the missing residues for chain L in PDB 3SE8 due to a misalignment between seqeuences from ATOM records and SEQRES. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:268: UserWarning: Could not find the missing residues for chain G in PDB 3SE8 due to a misalignment between seqeuences from ATOM records and SEQRES. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:268: UserWarning: Could not find the missing residues for chain L in PDB 3SE9 due to a misalignment between seqeuences from ATOM records and SEQRES. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:268: UserWarning: Could not find the missing residues for chain G in PDB 3SE9 due to a misalignment between seqeuences from ATOM records and SEQRES. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:268: UserWarning: Could not find the missing residues for chain E in PDB 3SGB due to a misalignment between seqeuences from ATOM records and SEQRES. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:268: UserWarning: Could not find the missing residues for chain E in PDB 3TGK due to a misalignment between seqeuences from ATOM records and SEQRES. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:342: UserWarning: Sequence length mismatch for chain I in PDB 4CPA between the raw PDB and the PDB in the data. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:268: UserWarning: Could not find the missing residues for chain D in PDB 4FTV due to a misalignment between seqeuences from ATOM records and SEQRES. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:268: UserWarning: Could not find the missing residues for chain E in PDB 4FTV due to a misalignment between seqeuences from ATOM records and SEQRES. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:439: UserWarning: Could not find the missing residues for chain N in PDB 4GXU due to a misalignment between seqeuences from ATOM records and SEQRES. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:268: UserWarning: Could not find the missing residues for chain L in PDB 4JPK due to a misalignment between seqeuences from ATOM records and SEQRES. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:439: UserWarning: Could not find the missing residues for chain A in PDB 4OZG due to a misalignment between seqeuences from ATOM records and SEQRES. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:268: UserWarning: Could not find the missing residues for chain H in PDB 4OZG due to a misalignment between seqeuences from ATOM records and SEQRES. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:268: UserWarning: Could not find the missing residues for chain G in PDB 4OZG due to a misalignment between seqeuences from ATOM records and SEQRES. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:439: UserWarning: Could not find the missing residues for chain A in PDB 4P23 due to a misalignment between seqeuences from ATOM records and SEQRES. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:268: UserWarning: Could not find the missing residues for chain A in PDB 4P5T due to a misalignment between seqeuences from ATOM records and SEQRES. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:439: UserWarning: Could not find the missing residues for chain E in PDB 1CSE due to a misalignment between seqeuences from ATOM records and SEQRES. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:439: UserWarning: Could not find the missing residues for chain E in PDB 1CSE due to a misalignment between seqeuences from ATOM records and SEQRES. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:439: UserWarning: Could not find the missing residues for chain E in PDB 1CSE due to a misalignment between seqeuences from ATOM records and SEQRES. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:439: UserWarning: Could not find the missing residues for chain E in PDB 1CSE due to a misalignment between seqeuences from ATOM records and SEQRES. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:439: UserWarning: Could not find the missing residues for chain E in PDB 1CSE due to a misalignment between seqeuences from ATOM records and SEQRES. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:439: UserWarning: Could not find the missing residues for chain E in PDB 1CSE due to a misalignment between seqeuences from ATOM records and SEQRES. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:268: UserWarning: Could not find the missing residues for chain A in PDB 1SBB due to a misalignment between seqeuences from ATOM records and SEQRES. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:268: UserWarning: Could not find the missing residues for chain A in PDB 1SBB due to a misalignment between seqeuences from ATOM records and SEQRES. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:268: UserWarning: Could not find the missing residues for chain A in PDB 1SBB due to a misalignment between seqeuences from ATOM records and SEQRES. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:268: UserWarning: Could not find the missing residues for chain A in PDB 1JCK due to a misalignment between seqeuences from ATOM records and SEQRES. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:268: UserWarning: Could not find the missing residues for chain A in PDB 1JCK due to a misalignment between seqeuences from ATOM records and SEQRES. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:268: UserWarning: Could not find the missing residues for chain A in PDB 1JCK due to a misalignment between seqeuences from ATOM records and SEQRES. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:268: UserWarning: Could not find the missing residues for chain A in PDB 1JCK due to a misalignment between seqeuences from ATOM records and SEQRES. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:268: UserWarning: Could not find the missing residues for chain A in PDB 1JCK due to a misalignment between seqeuences from ATOM records and SEQRES. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:268: UserWarning: Could not find the missing residues for chain A in PDB 1JCK due to a misalignment between seqeuences from ATOM records and SEQRES. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:268: UserWarning: Could not find the missing residues for chain A in PDB 1JCK due to a misalignment between seqeuences from ATOM records and SEQRES. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:268: UserWarning: Could not find the missing residues for chain A in PDB 1SBB due to a misalignment between seqeuences from ATOM records and SEQRES. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:268: UserWarning: Could not find the missing residues for chain A in PDB 1JCK due to a misalignment between seqeuences from ATOM records and SEQRES. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:268: UserWarning: Could not find the missing residues for chain A in PDB 1JCK due to a misalignment between seqeuences from ATOM records and SEQRES. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:268: UserWarning: Could not find the missing residues for chain A in PDB 1JCK due to a misalignment between seqeuences from ATOM records and SEQRES. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:439: UserWarning: Could not find the missing residues for chain B in PDB 2PCC due to a misalignment between seqeuences from ATOM records and SEQRES. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:439: UserWarning: Could not find the missing residues for chain B in PDB 2PCC due to a misalignment between seqeuences from ATOM records and SEQRES. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:439: UserWarning: Could not find the missing residues for chain B in PDB 2PCC due to a misalignment between seqeuences from ATOM records and SEQRES. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:439: UserWarning: Could not find the missing residues for chain B in PDB 2PCC due to a misalignment between seqeuences from ATOM records and SEQRES. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:439: UserWarning: Could not find the missing residues for chain B in PDB 2PCC due to a misalignment between seqeuences from ATOM records and SEQRES. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:439: UserWarning: Could not find the missing residues for chain B in PDB 2PCC due to a misalignment between seqeuences from ATOM records and SEQRES. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:439: UserWarning: Could not find the missing residues for chain B in PDB 2PCC due to a misalignment between seqeuences from ATOM records and SEQRES. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:439: UserWarning: Could not find the missing residues for chain B in PDB 2PCC due to a misalignment between seqeuences from ATOM records and SEQRES. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:439: UserWarning: Could not find the missing residues for chain B in PDB 2PCC due to a misalignment between seqeuences from ATOM records and SEQRES. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:439: UserWarning: Could not find the missing residues for chain B in PDB 2PCC due to a misalignment between seqeuences from ATOM records and SEQRES. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:439: UserWarning: Could not find the missing residues for chain B in PDB 2PCC due to a misalignment between seqeuences from ATOM records and SEQRES. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:439: UserWarning: Could not find the missing residues for chain B in PDB 2PCC due to a misalignment between seqeuences from ATOM records and SEQRES. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:268: UserWarning: Could not find the missing residues for chain H in PDB 2JEL due to a misalignment between seqeuences from ATOM records and SEQRES. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:268: UserWarning: Could not find the missing residues for chain H in PDB 2JEL due to a misalignment between seqeuences from ATOM records and SEQRES. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:268: UserWarning: Could not find the missing residues for chain H in PDB 2JEL due to a misalignment between seqeuences from ATOM records and SEQRES. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:268: UserWarning: Could not find the missing residues for chain H in PDB 2JEL due to a misalignment between seqeuences from ATOM records and SEQRES. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:268: UserWarning: Could not find the missing residues for chain H in PDB 2JEL due to a misalignment between seqeuences from ATOM records and SEQRES. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:268: UserWarning: Could not find the missing residues for chain H in PDB 2JEL due to a misalignment between seqeuences from ATOM records and SEQRES. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:268: UserWarning: Could not find the missing residues for chain H in PDB 2JEL due to a misalignment between seqeuences from ATOM records and SEQRES. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:268: UserWarning: Could not find the missing residues for chain H in PDB 2JEL due to a misalignment between seqeuences from ATOM records and SEQRES. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:268: UserWarning: Could not find the missing residues for chain H in PDB 2JEL due to a misalignment between seqeuences from ATOM records and SEQRES. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:268: UserWarning: Could not find the missing residues for chain H in PDB 2JEL due to a misalignment between seqeuences from ATOM records and SEQRES. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:268: UserWarning: Could not find the missing residues for chain H in PDB 2JEL due to a misalignment between seqeuences from ATOM records and SEQRES. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:268: UserWarning: Could not find the missing residues for chain H in PDB 2JEL due to a misalignment between seqeuences from ATOM records and SEQRES. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:268: UserWarning: Could not find the missing residues for chain H in PDB 2JEL due to a misalignment between seqeuences from ATOM records and SEQRES. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:268: UserWarning: Could not find the missing residues for chain H in PDB 2JEL due to a misalignment between seqeuences from ATOM records and SEQRES. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:268: UserWarning: Could not find the missing residues for chain H in PDB 2JEL due to a misalignment between seqeuences from ATOM records and SEQRES. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:268: UserWarning: Could not find the missing residues for chain H in PDB 2JEL due to a misalignment between seqeuences from ATOM records and SEQRES. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:268: UserWarning: Could not find the missing residues for chain H in PDB 2JEL due to a misalignment between seqeuences from ATOM records and SEQRES. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:268: UserWarning: Could not find the missing residues for chain H in PDB 2JEL due to a misalignment between seqeuences from ATOM records and SEQRES. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:268: UserWarning: Could not find the missing residues for chain H in PDB 2JEL due to a misalignment between seqeuences from ATOM records and SEQRES. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:268: UserWarning: Could not find the missing residues for chain H in PDB 2JEL due to a misalignment between seqeuences from ATOM records and SEQRES. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:268: UserWarning: Could not find the missing residues for chain H in PDB 2JEL due to a misalignment between seqeuences from ATOM records and SEQRES. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:268: UserWarning: Could not find the missing residues for chain H in PDB 2JEL due to a misalignment between seqeuences from ATOM records and SEQRES. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:268: UserWarning: Could not find the missing residues for chain H in PDB 2JEL due to a misalignment between seqeuences from ATOM records and SEQRES. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:268: UserWarning: Could not find the missing residues for chain H in PDB 2JEL due to a misalignment between seqeuences from ATOM records and SEQRES. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:268: UserWarning: Could not find the missing residues for chain H in PDB 2JEL due to a misalignment between seqeuences from ATOM records and SEQRES. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:268: UserWarning: Could not find the missing residues for chain H in PDB 2JEL due to a misalignment between seqeuences from ATOM records and SEQRES. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:268: UserWarning: Could not find the missing residues for chain H in PDB 2JEL due to a misalignment between seqeuences from ATOM records and SEQRES. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:268: UserWarning: Could not find the missing residues for chain H in PDB 2JEL due to a misalignment between seqeuences from ATOM records and SEQRES. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:268: UserWarning: Could not find the missing residues for chain H in PDB 2JEL due to a misalignment between seqeuences from ATOM records and SEQRES. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:268: UserWarning: Could not find the missing residues for chain H in PDB 2JEL due to a misalignment between seqeuences from ATOM records and SEQRES. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:268: UserWarning: Could not find the missing residues for chain H in PDB 2JEL due to a misalignment between seqeuences from ATOM records and SEQRES. Skipping adding missing residues for this chain.
#   warnings.warn(
# ...
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:342: UserWarning: Sequence length mismatch for chain B in PDB 3PL6 between the raw PDB and the PDB in the data. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:342: UserWarning: Sequence length mismatch for chain D in PDB 3PL6 between the raw PDB and the PDB in the data. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:326: UserWarning: Can't find chain E in raw PDB 3PL6. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:342: UserWarning: Sequence length mismatch for chain B in PDB 3PL6 between the raw PDB and the PDB in the data. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:342: UserWarning: Sequence length mismatch for chain D in PDB 3PL6 between the raw PDB and the PDB in the data. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:326: UserWarning: Can't find chain E in raw PDB 3PL6. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:342: UserWarning: Sequence length mismatch for chain B in PDB 3PL6 between the raw PDB and the PDB in the data. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:342: UserWarning: Sequence length mismatch for chain D in PDB 3PL6 between the raw PDB and the PDB in the data. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:326: UserWarning: Can't find chain E in raw PDB 3PL6. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:342: UserWarning: Sequence length mismatch for chain D in PDB 3DXA between the raw PDB and the PDB in the data. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:342: UserWarning: Sequence length mismatch for chain E in PDB 3DXA between the raw PDB and the PDB in the data. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:342: UserWarning: Sequence length mismatch for chain D in PDB 3DXA between the raw PDB and the PDB in the data. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:342: UserWarning: Sequence length mismatch for chain E in PDB 3DXA between the raw PDB and the PDB in the data. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:342: UserWarning: Sequence length mismatch for chain D in PDB 3DXA between the raw PDB and the PDB in the data. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:342: UserWarning: Sequence length mismatch for chain E in PDB 3DXA between the raw PDB and the PDB in the data. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:342: UserWarning: Sequence length mismatch for chain B in PDB 4H1L between the raw PDB and the PDB in the data. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:342: UserWarning: Sequence length mismatch for chain E in PDB 4H1L between the raw PDB and the PDB in the data. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:342: UserWarning: Sequence length mismatch for chain B in PDB 4H1L between the raw PDB and the PDB in the data. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:342: UserWarning: Sequence length mismatch for chain E in PDB 4H1L between the raw PDB and the PDB in the data. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:342: UserWarning: Sequence length mismatch for chain D in PDB 1BD2 between the raw PDB and the PDB in the data. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:342: UserWarning: Sequence length mismatch for chain E in PDB 1BD2 between the raw PDB and the PDB in the data. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:342: UserWarning: Sequence length mismatch for chain D in PDB 1BD2 between the raw PDB and the PDB in the data. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:342: UserWarning: Sequence length mismatch for chain E in PDB 1BD2 between the raw PDB and the PDB in the data. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:342: UserWarning: Sequence length mismatch for chain D in PDB 1BD2 between the raw PDB and the PDB in the data. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:342: UserWarning: Sequence length mismatch for chain E in PDB 1BD2 between the raw PDB and the PDB in the data. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:342: UserWarning: Sequence length mismatch for chain D in PDB 1BD2 between the raw PDB and the PDB in the data. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:342: UserWarning: Sequence length mismatch for chain E in PDB 1BD2 between the raw PDB and the PDB in the data. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:342: UserWarning: Sequence length mismatch for chain D in PDB 1BD2 between the raw PDB and the PDB in the data. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:342: UserWarning: Sequence length mismatch for chain E in PDB 1BD2 between the raw PDB and the PDB in the data. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:342: UserWarning: Sequence length mismatch for chain D in PDB 1BD2 between the raw PDB and the PDB in the data. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:342: UserWarning: Sequence length mismatch for chain E in PDB 1BD2 between the raw PDB and the PDB in the data. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:342: UserWarning: Sequence length mismatch for chain D in PDB 1BD2 between the raw PDB and the PDB in the data. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:342: UserWarning: Sequence length mismatch for chain E in PDB 1BD2 between the raw PDB and the PDB in the data. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:342: UserWarning: Sequence length mismatch for chain D in PDB 1BD2 between the raw PDB and the PDB in the data. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:342: UserWarning: Sequence length mismatch for chain E in PDB 1BD2 between the raw PDB and the PDB in the data. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:342: UserWarning: Sequence length mismatch for chain D in PDB 1BD2 between the raw PDB and the PDB in the data. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:342: UserWarning: Sequence length mismatch for chain E in PDB 1BD2 between the raw PDB and the PDB in the data. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:342: UserWarning: Sequence length mismatch for chain D in PDB 1BD2 between the raw PDB and the PDB in the data. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:342: UserWarning: Sequence length mismatch for chain E in PDB 1BD2 between the raw PDB and the PDB in the data. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:342: UserWarning: Sequence length mismatch for chain D in PDB 1BD2 between the raw PDB and the PDB in the data. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:342: UserWarning: Sequence length mismatch for chain E in PDB 1BD2 between the raw PDB and the PDB in the data. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:342: UserWarning: Sequence length mismatch for chain D in PDB 1BD2 between the raw PDB and the PDB in the data. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:342: UserWarning: Sequence length mismatch for chain E in PDB 1BD2 between the raw PDB and the PDB in the data. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:342: UserWarning: Sequence length mismatch for chain D in PDB 1BD2 between the raw PDB and the PDB in the data. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:342: UserWarning: Sequence length mismatch for chain E in PDB 1BD2 between the raw PDB and the PDB in the data. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:342: UserWarning: Sequence length mismatch for chain D in PDB 1BD2 between the raw PDB and the PDB in the data. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:342: UserWarning: Sequence length mismatch for chain E in PDB 1BD2 between the raw PDB and the PDB in the data. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:342: UserWarning: Sequence length mismatch for chain D in PDB 1BD2 between the raw PDB and the PDB in the data. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:342: UserWarning: Sequence length mismatch for chain E in PDB 1BD2 between the raw PDB and the PDB in the data. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:342: UserWarning: Sequence length mismatch for chain D in PDB 1BD2 between the raw PDB and the PDB in the data. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:342: UserWarning: Sequence length mismatch for chain E in PDB 1BD2 between the raw PDB and the PDB in the data. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:342: UserWarning: Sequence length mismatch for chain D in PDB 1BD2 between the raw PDB and the PDB in the data. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:342: UserWarning: Sequence length mismatch for chain E in PDB 1BD2 between the raw PDB and the PDB in the data. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:217: UserWarning: Mutation (5, 'Y', 'F') is already applied to chain C in PDB 3QFJ
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:342: UserWarning: Sequence length mismatch for chain D in PDB 3QFJ between the raw PDB and the PDB in the data. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:342: UserWarning: Sequence length mismatch for chain E in PDB 3QFJ between the raw PDB and the PDB in the data. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:217: UserWarning: Mutation (27, 'D', 'F') is already applied to chain D in PDB 4JFF
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:217: UserWarning: Mutation (28, 'R', 'L') is already applied to chain D in PDB 4JFF
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:217: UserWarning: Mutation (50, 'I', 'T') is already applied to chain D in PDB 4JFF
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:217: UserWarning: Mutation (52, 'S', 'R') is already applied to chain D in PDB 4JFF
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:217: UserWarning: Mutation (53, 'N', 'E') is already applied to chain D in PDB 4JFF
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:217: UserWarning: Mutation (71, 'Y', 'H') is already applied to chain D in PDB 4JFF
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:217: UserWarning: Mutation (93, 'V', 'D') is already applied to chain D in PDB 4JFF
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:217: UserWarning: Mutation (94, 'A', 'G') is already applied to chain D in PDB 4JFF
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:217: UserWarning: Mutation (96, 'K', 'R') is already applied to chain D in PDB 4JFF
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:217: UserWarning: Mutation (97, 'S', 'L') is already applied to chain D in PDB 4JFF
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:217: UserWarning: Mutation (44, 'L', 'P') is already applied to chain E in PDB 4JFF
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:217: UserWarning: Mutation (50, 'S', 'W') is already applied to chain E in PDB 4JFF
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:217: UserWarning: Mutation (51, 'V', 'G') is already applied to chain E in PDB 4JFF
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:217: UserWarning: Mutation (52, 'G', 'P') is already applied to chain E in PDB 4JFF
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:217: UserWarning: Mutation (53, 'I', 'F') is already applied to chain E in PDB 4JFF
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:217: UserWarning: Mutation (100, 'T', 'M') is already applied to chain E in PDB 4JFF
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:217: UserWarning: Mutation (102, 'E', 'G') is already applied to chain E in PDB 4JFF
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:217: UserWarning: Mutation (103, 'L', 'W') is already applied to chain E in PDB 4JFF
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:217: UserWarning: Mutation (104, 'F', 'Q') is already applied to chain E in PDB 4JFF
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:342: UserWarning: Sequence length mismatch for chain E in PDB 5D2L between the raw PDB and the PDB in the data. Skipping adding missing residues for this chain.
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:217: UserWarning: Mutation (26, 'D', 'Y') is already applied to chain D in PDB 4L3E
#   warnings.warn(
# /home/shaffei/Work/papers/ppb_aff/pdb_processor.py:217: UserWarning: Mutation (98, 'L', 'W') is already applied to chain E in PDB 4L3E
#   warnings.warn(
